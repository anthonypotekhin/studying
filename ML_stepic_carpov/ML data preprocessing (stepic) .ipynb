# %% [markdown]
# ## ПРЕПОДГОТОВКА ДАННЫХ (data preprocessing)
# на входе имеем:
# - датасэт с логами: пользователь, степ, действие, фиксация по времени
# - датасэт: пользователь, степ, статус решения стэпа, фиксация времени
#
# #### Цель подготовить данные к анализу

# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Считаываем данные о действиях, которые совершают студенты со стэпами
#
# они хранятся здесь если что: https://stepik.org/media/attachments/course/4852/event_data_train.zip
#
# 1) step_id - id стэпа
# 2) user_id - анонимизированный id юзера
# 3) timestamp - время наступления события в формате unix date
# 4) action - событие, возможные значения:
# - discovered - пользователь перешел на стэп
# - viewed - просмотр шага,
# - started_attempt - начало попытки решить шаг, ранее нужно было явно нажать на кнопку - начать решение, перед тем как приступить к решению практического шага
# - passed - удачное решение практического шага

# %%
events_data= pd.read_csv('/Users/tony_builder/tony. Личное/IT/Mashine Learning/event_data_train.csv')
events_data
# Out:
#          step_id   timestamp      action  user_id
# 0          32815  1434340848      viewed    17632
# 1          32815  1434340848      passed    17632
# 2          32815  1434340848  discovered    17632
# 3          32811  1434340895  discovered    17632
# 4          32811  1434340895      viewed    17632
# ...          ...         ...         ...      ...
# 3480698    33375  1526772685      viewed    11677
# 3480699    32815  1526772750      viewed     5198
# 3480700    32815  1526772750  discovered     5198
# 3480701    32815  1526772750      passed     5198
# 3480702    33892  1526772811      viewed    18526
#
# [3480703 rows x 4 columns]

# %% [markdown]
# Считываем данные  о времени и статусах сабмитов к практическим заданиям
#
# они хранятся здесь если что: https://stepik.org/media/attachments/course/4852/submissions_data_train.zip
#
# 1) step_id - id стэпа
# 2) timestamp - время отправки решения в формате unix date
# 3) submission_status - статус решения
# 4) user_id - анонимизированный id юзера

# %%
submissions_data = pd.read_csv('/Users/tony_builder/tony. Личное/IT/Mashine Learning/submissions_data_train.csv')

submissions_data
# Out:
#         step_id   timestamp submission_status  user_id
# 0         31971  1434349275           correct    15853
# 1         31972  1434348300           correct    15853
# 2         31972  1478852149             wrong    15853
# 3         31972  1478852164           correct    15853
# 4         31976  1434348123             wrong    15853
# ...         ...         ...               ...      ...
# 509099   120745  1501946959             wrong     2615
# 509100   120745  1503059927           correct    13177
# 509101   120745  1506348153             wrong    15253
# 509102   120745  1523035316             wrong     1424
# 509103   120745  1523382825             wrong     9422
#
# [509104 rows x 4 columns]

# %% [markdown]
# ### формат времени - это количество секунд, которые прошли с 1 января 1970 года
#
# полезные ссылки:
# 1) работа со временем в pandas https://medium.datadriveninvestor.com/how-to-work-with-dates-in-pandas-like-a-pro-a84055a4819d
# 2) примеры работы со временем в pandas: https://www.geeksforgeeks.org/python-working-with-date-and-time-using-pandas/
# 3) работа с модулем datetime https://python-scripts.com/datetime-time-python

# %% [markdown]
# отвлечемся - немного поработаем со временем на примерах

# %%
# узнать текущую дату - код выведет кортеж (год, месяц, день, час, минут, секунд...)
import datetime                 # нужно импортировать модуль datetime
now = datetime.datetime.now()
display(now)
print(now)

# но объект не итерируемый! код ниже выдаст ошибку
# print(tuple(now)[0]) 

# а значит нужно пользоваться встроенными методами:
print(now.year, now.month, now.day, now.hour, now.minute, now.second)   # выведет значение типа int, с которым уже можно работать
# Out:
# datetime.datetime(2023, 2, 17, 12, 7, 53, 134298)
# 2023-02-17 12:07:53.134298
# 2023 2 17 12 7 53
# 2028

# %% [markdown]
# pandas.Series.dt.year возвращает год даты и времени.
#
# pandas.Series.dt.month возвращает месяц даты и времени.
#
# pandas.Series.dt.day возвращает день даты и времени.
#
# pandas.Series.dt.hour возвращает час даты и времени.
#
# pandas.Series.dt.minute возвращает минуту даты и времени.

# %%
# разбить дату на отдельные элементы можно так:

rng = pd.DataFrame()
rng['date'] = pd.date_range('1/1/2011', periods = 72, freq ='H')
 
# Print the dates in dd-mm-yy format
rng[:5]

# заодно напомню себе, как можно легко экранировать исключить убрать целый блок кода из выполнения 
"""
# Create features for year, month, day, hour, and minute
rng['year'] = rng['date'].dt.year
rng['month'] = rng['date'].dt.month
rng['day'] = rng['date'].dt.day
rng['hour'] = rng['date'].dt.hour
rng['minute'] = rng['date'].dt.minute  
"""
rng['year'] = rng['date'].dt.year
rng['month'] = rng['date'].dt.month
rng['day'] = rng['date'].dt.day
rng['hour'] = rng['date'].dt.hour
rng['minute'] = rng['date'].dt.minute  

rng
# Out:
#                   date  year  month  day  hour  minute
# 0  2011-01-01 00:00:00  2011      1    1     0       0
# 1  2011-01-01 01:00:00  2011      1    1     1       0
# 2  2011-01-01 02:00:00  2011      1    1     2       0
# 3  2011-01-01 03:00:00  2011      1    1     3       0
# 4  2011-01-01 04:00:00  2011      1    1     4       0
# ..                 ...   ...    ...  ...   ...     ...
# 67 2011-01-03 19:00:00  2011      1    3    19       0
# 68 2011-01-03 20:00:00  2011      1    3    20       0
# 69 2011-01-03 21:00:00  2011      1    3    21       0
# 70 2011-01-03 22:00:00  2011      1    3    22       0
# 71 2011-01-03 23:00:00  2011      1    3    23       0
#
# [72 rows x 6 columns]

# %% [markdown]
# добавим колонку с переведенным временем в привычный формат
#
# формат (тип) этих данных - datetime64[ns]

# %%
events_data['date'] = pd.to_datetime(events_data.timestamp, unit = 's')
events_data.head()
# Out:
#    step_id   timestamp      action  user_id                date
# 0    32815  1434340848      viewed    17632 2015-06-15 04:00:48
# 1    32815  1434340848      passed    17632 2015-06-15 04:00:48
# 2    32815  1434340848  discovered    17632 2015-06-15 04:00:48
# 3    32811  1434340895  discovered    17632 2015-06-15 04:01:35
# 4    32811  1434340895      viewed    17632 2015-06-15 04:01:35

# %%
events_data.dtypes
# Out:
# step_id               int64
# timestamp             int64
# action               object
# user_id               int64
# date         datetime64[ns]
# dtype: object

# %% [markdown]
# можно работать с этими данными о времени
#
# например, найти минимальное (то есть по сути время первого обращения к курсу):

# %%
events_data.date.min()
# Out:
# Timestamp('2015-06-15 04:00:48')

# %% [markdown]
# посмотрим какие уникальные данные вообще встречаются в графе событий:

# %%
events_data.action.unique()
# Out:
# array(['viewed', 'passed', 'discovered', 'started_attempt'], dtype=object)

# %% [markdown]
# создадим новую колонку

# %%
events_data['day'] = events_data.date.dt.date
events_data.head()
# Out:
#    step_id   timestamp      action  user_id                date         day
# 0    32815  1434340848      viewed    17632 2015-06-15 04:00:48  2015-06-15
# 1    32815  1434340848      passed    17632 2015-06-15 04:00:48  2015-06-15
# 2    32815  1434340848  discovered    17632 2015-06-15 04:00:48  2015-06-15
# 3    32811  1434340895  discovered    17632 2015-06-15 04:01:35  2015-06-15
# 4    32811  1434340895      viewed    17632 2015-06-15 04:01:35  2015-06-15

# %% [markdown]
# Теперь посмотрим сколько людей в какой день записалось
#
# для этого сгруппируем по колонке день, и возьмем число уникальных юзеров из колонки user_id

# %%
events_data.groupby('day') \
    .user_id.nunique().head()
# Out:
# day
# 2015-06-15    705
# 2015-06-16    526
# 2015-06-17    440
# 2015-06-18    411
# 2015-06-19    377
# Name: user_id, dtype: int64

# %% [markdown]
# неудобно данные в таком виде оценить - строим график
#
# где х - это переменная столбца День (дата)
#
# у - это значение уникальных пользователей

# %%
events_data.groupby('day') \
    .user_id.nunique().plot()
# Out:
# <AxesSubplot: xlabel='day'>

# %% [markdown]
# настроим размер (масштаб) графика для удобства восприятия

# %%
# Надстройка для изменения размера графика
sns.set(rc={'figure.figsize': (9,6)})

# %%
events_data.groupby('day') \
    .user_id.nunique().plot()
# Out:
# <AxesSubplot: xlabel='day'>

# %% [markdown]
# Теперь посмотрим кто успешно решал степы и в каком количестве
#
# для этого:
# - отфильтруем датасэт по показателю passed в графе action
# - сгруппируем датасэт по переменной пользователя (чтобы он посчитал всех уникальных пользователей)
# - аггрегируем данные по графе step_id (в данном случае посчитаем количество пройденных степов)
# - заменим имя колонки, в которую мы все это собираем (step_id -> passed_step)

# %%
events_passed = events_data[events_data.action == 'passed'] \
    .groupby('user_id', as_index = False) \
    .agg({'step_id': 'count'}) \
    .rename(columns = {'step_id': 'passed_step'})

events_passed
# Out:
#        user_id  passed_step
# 0            2            9
# 1            3           87
# 2            5           11
# 3            7            1
# 4            8           84
# ...        ...          ...
# 17257    26789            2
# 17258    26790            8
# 17259    26794           69
# 17260    26797           10
# 17261    26798           12
#
# [17262 rows x 2 columns]

# %% [markdown]
# теперь построим гистограмму распределения:
# - по оси х здесь будет число сданных степов юзерами
# - по оси у - частота появления такого события

# %%
events_passed.passed_step.hist()
# Out:
# <AxesSubplot: >

# %%
events_passed.sort_values(['passed_step'], ascending = False)
# Out:
#        user_id  passed_step
# 8631     13365          198
# 16510    25632          198
# 2995      4546          198
# 13758    21395          198
# 10641    16489          198
# ...        ...          ...
# 12116    18806            1
# 12114    18802            1
# 12108    18795            1
# 4395      6733            1
# 12597    19549            1
#
# [17262 rows x 2 columns]

# %% [markdown]
# Что мы видим?
#
# что в нашем аггрегированном датасэте есть значение числа СДАННЫХ (решенных) степов равное 1
#
# это значит, что мы ПОТЕРЯЛИ всех пользователей, которые НЕ РЕШИЛИ НИ ОДНОГО степа.
#
# ### вывод: решение неверное.

# %% [markdown]
# Что делаем дальше?
#
# воспользуемся ***pivot таблицами***
#
# что она сделает: она перепишет таблицу таким образом, что :
# 1) нужные нам данные из колонки юзеров станут индексами
# 2) именами колонок станут названия колонки action (увидел, решил, впервые открыл, первая попытка решения)
# 3) значениями в колонках станет посчет количества каждого из действий для каждого из юзеров
# 4) а те позиции, которые окажутся пустыми - заполнит нулями

# %%
# включаем 0 в выборку
events_data.pivot_table(index='user_id', 
                        columns='action',                   # здесь назначили имена колонок
                        values='step_id',                   # здесь сообщили откуда взять значения для заполнения
                        aggfunc='count',                    # здесь сказали что делать с этими значениями
                        fill_value=0)\
                            .reset_index().head()           # здесь "сбросили" индексы, заведя их в отдельную колонку 


# чем эта структура удобнее, чем та, что ниже? - доступ к именам колонок (а значит и к значениям) проще и удобнее
# Out:
# action  user_id  discovered  passed  started_attempt  viewed
# 0             1           1       0                0       1
# 1             2           9       9                2      10
# 2             3          91      87               30     192
# 3             5          11      11                4      12
# 4             7           1       1                0       1

# %%
# для наглядности уберу сброс индексов, чтобы увидеть как таблица выглядит на выходе


events_uniq = events_data.pivot_table(index='user_id', 
                        columns='action',                   # здесь назначили имена колонок
                        values='step_id',                   # здесь сообщили откуда взять значения для заполнения
                        aggfunc='count',                    # здесь сказали что делать с этими значениями
                        fill_value=0)\
                             

events_uniq.head()
# Out:
# action   discovered  passed  started_attempt  viewed
# user_id
# 1                 1       0                0       1
# 2                 9       9                2      10
# 3                91      87               30     192
# 5                11      11                4      12
# 7                 1       1                0       1

# %% [markdown]
# Теперь можно посмотреть на распределение активности пользователей
#
# (например, по типу discovered - то есть тех, кто впервые открыл некоторый степ)

# %%
events_uniq.discovered.hist()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Теперь перейдем к обработке данных из таблицы, хранящей данные о результате решений степов

# %% [markdown]
# добавим столбцы по удобоваримой дате

# %%
submissions_data['date'] = pd.to_datetime(submissions_data.timestamp, unit = 's')
submissions_data['day'] = submissions_data.date.dt.date
submissions_data.head()
# Out:
#    step_id   timestamp submission_status  user_id                date  \
# 0    31971  1434349275           correct    15853 2015-06-15 06:21:15
# 1    31972  1434348300           correct    15853 2015-06-15 06:05:00
# 2    31972  1478852149             wrong    15853 2016-11-11 08:15:49
# 3    31972  1478852164           correct    15853 2016-11-11 08:16:04
# 4    31976  1434348123             wrong    15853 2015-06-15 06:02:03
#
#           day
# 0  2015-06-15
# 1  2015-06-15
# 2  2016-11-11
# 3  2016-11-11
# 4  2015-06-15

# %% [markdown]
# посмотрим сколько за всю историю курса было правильных и неправильных решений каждого степа
#
# разумеется, для каждого пользователя, который решал степы

# %%
users_scores = submissions_data.pivot_table(index='user_id', 
                        columns='submission_status', 
                        values='step_id', 
                        aggfunc='count', 
                        fill_value=0).reset_index()
users_scores.head()
# Out:
# submission_status  user_id  correct  wrong
# 0                        2        2      0
# 1                        3       29     23
# 2                        5        2      2
# 3                        8        9     21
# 4                       14        0      1

# %%
# вспомогательный код только для понимания, как по сути выглядит таблица (верхняя - для удобства работы)

submissions_data.pivot_table(index='user_id', 
                        columns='submission_status', 
                        values='step_id', 
                        aggfunc='count', 
                        fill_value=0).head()
# Out:
# submission_status  correct  wrong
# user_id
# 2                        2      0
# 3                       29     23
# 5                        2      2
# 8                        9     21
# 14                       0      1

# %% [markdown]
# ### Теперь определим число бросивших курс посредством анализа промежутка времени
# Зачем? зная его  можно утверждать, что студент бросил курс

# %% [markdown]
# возьмем только интересующие нас данные: юзер, день, временная метка

# %%
events_data[['user_id', 'day', 'timestamp']].head()
# Out:
#    user_id         day   timestamp
# 0    17632  2015-06-15  1434340848
# 1    17632  2015-06-15  1434340848
# 2    17632  2015-06-15  1434340848
# 3    17632  2015-06-15  1434340895
# 4    17632  2015-06-15  1434340895

# %% [markdown]
# удалим дубликаты с помощью метода drop_duplicates(), который уберет все строки, содержащие дубликаты

# %%
events_data[['user_id', 'day', 'timestamp']].head().drop_duplicates()
# Out:
#    user_id         day   timestamp
# 0    17632  2015-06-15  1434340848
# 3    17632  2015-06-15  1434340895

# %% [markdown]
# уберем дубликаты только для колонок юзер и день
#
# останутся только строчки для каждого юзера со временем когда он был онлайн

# %%
# Удаляем дубликаты только по айди и дням
events_data[['user_id', 'day', 'timestamp']].drop_duplicates(subset=['user_id', 'day']).head()
# Out:
#     user_id         day   timestamp
# 0     17632  2015-06-15  1434340848
# 36    12494  2015-06-15  1434341931
# 59      442  2015-06-15  1434342029
# 62    22254  2015-06-15  1434342042
# 94     6646  2015-06-15  1434342230

# %% [markdown]
# для наглядности смотрим как выглядит такой датасэт отсортированный по пользователям: видим, что для каждого пользователя есть множество значений дней и временных меток, когда он был онлайн

# %%
events_data[['user_id', 'day', 'timestamp']].drop_duplicates(subset=['user_id', 'day']).sort_values(['user_id']).head()
# Out:
#          user_id         day   timestamp
# 1347416        1  2016-09-02  1472827464
# 2874398        2  2017-12-27  1514383364
# 3073427        2  2018-02-21  1519226966
# 740499         3  2015-10-11  1444552901
# 706958         3  2015-09-06  1441533919

# %% [markdown]
# Теперь для каждого пользователя мы находим уникальные временные метки, когда он был онлайн:
# - для этого отбираем три колонки датасэта (уже делали выше)
# - убираем дубликаты (делали выше)
# - группируем по пользователям (чтобы в датасэте в колонке Пользователь не повторялся несколько раз)
# - и для колонки временной метки применяем метод аппликации (apply) для сбора всех временных меток в некий список

# %%
# Для каждого пользователя находим уникальные таймстемпы
events_data[['user_id', 'day', 'timestamp']].drop_duplicates(subset=['user_id', 'day']) \
    .groupby('user_id')['timestamp'].apply(list).head()
# Out:
# user_id
# 1                                         [1472827464]
# 2                             [1514383364, 1519226966]
# 3    [1434358476, 1441257725, 1441440209, 144153391...
# 5                             [1466156809, 1499859621]
# 7                                         [1521634660]
# Name: timestamp, dtype: object

# %% [markdown]
# вспогательный код для понимания - работа функции diff()
#
# для списка работает следующим образом - возвращает массив разниц между соседними элементами списка

# %%
print(np.diff([2,9,1,5]))

print(np.diff(sorted([2,9,1,5])))
# Out:
# [ 7 -8  4]
# [1 3 4]

# %% [markdown]
# Теперь применим эту функцию для расчета разницы между временными меткаим для каждого уникального пользователя:

# %%
# Для каждого пользователя находим разницу по времени между его нахождениями на сайте
events_data[['user_id', 'day', 'timestamp']].drop_duplicates(subset=['user_id', 'day']) \
    .groupby('user_id')['timestamp'].apply(list) \
        .apply(np.diff).head(20)
# Out:
# user_id
# 1                                                    []
# 2                                             [4843602]
# 3      [6899249, 182484, 93710, 2768870, 171400, 78712]
# 5                                            [33702812]
# 7                                                    []
# 8                                              [863484]
# 9                                                    []
# 11                                                   []
# 14                                                   []
# 16    [50930, 169538, 198580, 60037, 107104, 64636, ...
# 17                                                   []
# 18                                                   []
# 20                                                   []
# 22    [83724, 114165, 51041, 122754, 87609, 58592, 8...
# 24                                                   []
# 25                                              [76445]
# 26                                              [62937]
# 28                                                   []
# 30    [145570, 169476, 271367, 331527, 85955, 106315...
# 31                                              [71256]
# Name: timestamp, dtype: object

# %% [markdown]
# на выходе видим, что чем больше значений временных меток, то разумеется тем больше значений разниц между соседними временными метками

# %% [markdown]
# теперь соберем все эти массивы разниц во временных метках между посещениями для каждого юзера.
#
# суть тут в том, что мы считаем разницу во временных метках именно для БЛИЖАЙШИХ соседних днях посещений пользователем сайта.
#
# это означает, что нам не важно когда это было - в феврале или в мае. важно, чтобы ДЛЯ КАЖДОГО пользователя считалась именно эта уникальная разница между БЛИЖАЙШИМИ соседними днями посещений

# %%
gap_data = events_data[['user_id', 'day', 'timestamp']].drop_duplicates(subset=['user_id', 'day']) \
    .groupby('user_id')['timestamp'].apply(list) \
        .apply(np.diff).values

gap_data            # тут получим массив массивов с этими разницами во времени
# Out:
# array([array([], dtype=int64), array([4843602]),
#        array([6899249,  182484,   93710, 2768870,  171400,   78712]), ...,
#        array([   86128,   136759,    94899,  1422583, 14347289,   505061,
#                  98252,    57019])                                       ,
#        array([1567990]), array([], dtype=int64)], dtype=object)

# %% [markdown]
# соберем этот массив массивов в единый массив при помощи функции конкатенации np.concatenate

# %%
np.concatenate(gap_data, axis=0)    # ось 0 указываем для пояснения, что мы используем строки
# Out:
# array([4843602, 6899249,  182484, ...,   98252,   57019, 1567990])

# %% [markdown]
# обернем полученный массив в пандасовскую серию

# %%
# gap_data = pd.Series(np.concatenate(gap_data, axis=0))    # почему-то выводит ошибку о запрете деления на ноль

gap_data = pd.Series(np.hstack(gap_data))

gap_data = gap_data/ (24*60*60)     # переведем значение разниц временных меток в дни (в сутках)

gap_data
# Out:
# 0         56.060208
# 1         79.852419
# 2          2.112083
# 3          1.084606
# 4         32.047106
#             ...
# 97867    166.056586
# 97868      5.845613
# 97869      1.137176
# 97870      0.659942
# 97871     18.148032
# Length: 97872, dtype: float64

# %% [markdown]
# строим гистограмму распределения:
# - по оси х - разница в посещениях (в днях)
# - по оси у - частота появления таких значений

# %%
gap_data.hist()
# Out:
# <AxesSubplot: >

# %% [markdown]
# картинка несильно содержательна, поэтому фильтруем по значению временных меток (просто уменьшаем масштаб по сути))

# %%
gap_data[gap_data < 200].hist()
# Out:
# <AxesSubplot: >

# %% [markdown]
# видим, что большая часть укладывается в диапазон от 0 до 25 дней (именно столько БОЛЬШАЯ часть пользователей делает перерыв между заходами на сайт и потом ВОЗВРАЩАЕТСЯ)

# %% [markdown]
# теперь проверим, какое число дней является пограничным для возврата на сайт для 5% людей.
#
# для этого возьмем квантиль 0.95 для всех значений разниц во времени - это будет означать, что из всей массы наблюдений по переменной (разница между заходом и выходом с сайта) вероятность попасть в дипазон от 0 до n-дней составляет 95%
#
# а именно пограничное значение разницы во времени будет равняться квантилю от 0.95

# %%
gap_data.quantile(0.95)         # вернет предельное количество дней, после которого лишь 5% вернется на сайт
# Out:
# 59.760440972222156

# %%
gap_data.quantile(0.98)         # вернет количество дней, после которого лишь 2% вернется на сайт
# Out:
# 179.1959025462963

# %% [markdown]
# интересно, какое количество дней является пограничным для половины людей?
#
# то есть вероятность, что человек зашел на сайт, посмотрел материалы и вышел - когда он вернется с 50% вероятностью?
#
# по сути это шанс 50/50

# %%
gap_data.quantile(0.5)          # всего лишь 32 часа стоит ждать. и вероятность снижается с каждым днем (статистически)
# Out:
# 1.3154803240740742

# %% [markdown]
# Возьмем более щадящий порог для установления характеристики "Покинул курс навсегда":
#
# 90% возвращается спустя 18 дней, 10% более чем через 18 дней

# %%
gap_data.quantile(0.9)
# Out:
# 18.325995370370403

# %% [markdown]
# ### Отвлечемся - практическая задачка:
# найти id Анатолия Карпова, под которым он фигурирует в данных events_data_train и submissions_data_train.

# %%
events_data
# Out:
#          step_id   timestamp      action  user_id                date  \
# 0          32815  1434340848      viewed    17632 2015-06-15 04:00:48
# 1          32815  1434340848      passed    17632 2015-06-15 04:00:48
# 2          32815  1434340848  discovered    17632 2015-06-15 04:00:48
# 3          32811  1434340895  discovered    17632 2015-06-15 04:01:35
# 4          32811  1434340895      viewed    17632 2015-06-15 04:01:35
# ...          ...         ...         ...      ...                 ...
# 3480698    33375  1526772685      viewed    11677 2018-05-19 23:31:25
# 3480699    32815  1526772750      viewed     5198 2018-05-19 23:32:30
# 3480700    32815  1526772750  discovered     5198 2018-05-19 23:32:30
# 3480701    32815  1526772750      passed     5198 2018-05-19 23:32:30
# 3480702    33892  1526772811      viewed    18526 2018-05-19 23:33:31
#
#                 day
# 0        2015-06-15
# 1        2015-06-15
# 2        2015-06-15
# 3        2015-06-15
# 4        2015-06-15
# ...             ...
# 3480698  2018-05-19
# 3480699  2018-05-19
# 3480700  2018-05-19
# 3480701  2018-05-19
# 3480702  2018-05-19
#
# [3480703 rows x 6 columns]

# %%
submissions_data
# Out:
#         step_id   timestamp submission_status  user_id                date  \
# 0         31971  1434349275           correct    15853 2015-06-15 06:21:15
# 1         31972  1434348300           correct    15853 2015-06-15 06:05:00
# 2         31972  1478852149             wrong    15853 2016-11-11 08:15:49
# 3         31972  1478852164           correct    15853 2016-11-11 08:16:04
# 4         31976  1434348123             wrong    15853 2015-06-15 06:02:03
# ...         ...         ...               ...      ...                 ...
# 509099   120745  1501946959             wrong     2615 2017-08-05 15:29:19
# 509100   120745  1503059927           correct    13177 2017-08-18 12:38:47
# 509101   120745  1506348153             wrong    15253 2017-09-25 14:02:33
# 509102   120745  1523035316             wrong     1424 2018-04-06 17:21:56
# 509103   120745  1523382825             wrong     9422 2018-04-10 17:53:45
#
#                day
# 0       2015-06-15
# 1       2015-06-15
# 2       2016-11-11
# 3       2016-11-11
# 4       2015-06-15
# ...            ...
# 509099  2017-08-05
# 509100  2017-08-18
# 509101  2017-09-25
# 509102  2018-04-06
# 509103  2018-04-10
#
# [509104 rows x 6 columns]

# %% [markdown]
# #### Логика рассуждений:
# 1) Вероятно, преподаватель (создатель) курса находится в числе тех, кто за всю историю курса заходил на этот курс
# 2) скорее всего, он не только заходит, но снова и снова решает задачи курса, проверяя какие ответы принимает система

# %% [markdown]
# посчитаем количество уникальных дней для каждого пользователя в обоих датасэтах:
# - группируем по пользователям
# - собираем данные из колонки дни - считаем количество для каждого пользователя
# - переименовываем результируюущую колонку
# - сортируем по убыванию (то есть в шапке будут польлзователи, у которых больше всех число уникальных дней пребывания на сайте)

# %%
events_data\
    .groupby('user_id')\
    .agg({'day':'count'})\
        .rename(columns = {'day' : 'num_days'})\
            .sort_values('num_days', ascending=False)\
                .head(10)
# Out:
#          num_days
# user_id
# 20907       33043
# 10794       16436
# 25279       10179
# 1046         9095
# 3572         7905
# 11770        6641
# 9546         6387
# 761          4592
# 8363         3918
# 13602        3480

# %%
submissions_data\
    .groupby('user_id')\
    .agg({'day':'count'})\
        .rename(columns = {'day' : 'num_days'})\
            .sort_values('num_days', ascending=False)\
                .head(10)
# Out:
#          num_days
# user_id
# 12265        1051
# 3643          948
# 1046          934
# 14454         920
# 643           888
# 20236         881
# 635           853
# 1468          768
# 24995         625
# 18065         616

# %% [markdown]
# смотрим на обе таблицы - пользователь, который присутствует в обеих - под номером 1046

# %% [markdown]
# ### Другое решение:
# найти самого первого, кто решил последний степ (скорее всего это будет тестировщик, но в нашем случае этот тестировщик и преподаватель - один человек):
# - фильтруем так, что оставляем только того, у кого в графе действий есть "решил"
# - локализуем только тех пользователей, кто решил последний степ - то есть имеет максимальное значение степа
# - сортируем данные по столбцу точного времени фиксации результата
# - берем первого в списке - это будет наш искомый человек

# %%
tmp_data = events_data.query("action == 'passed' ")\
    .loc[events_data.step_id == max(events_data.step_id)]\
        .sort_values('timestamp')\
            .head(1)
    
display(tmp_data)

print('Номер id интересующего человека - ', tmp_data.iloc[0]['user_id'])    # взять конкретное значение из датасэт dataframe
# Out:
#          step_id   timestamp  action  user_id                date         day
# 1780990   158433  1485263664  passed     1046 2017-01-24 13:14:24  2017-01-24
# Номер id интересующего человека -  1046

# %% [markdown]
# ### Продолжаем решение основной задачи - ищем пользователей, которые реально покинули курс:
# - он не появляется больше 30 дней (приняли из предыдущих рассуждений - можно посчитать квантиль для 92%)
# - он не получил сертификат, т.е точно не заканчивал курс

# %% [markdown]
# #### 1) узнаем точное время, когда пользователь последний раз был на сайте

# %%
# посчитаем для каждго пользователя максимальное значение временной метки (то есть точное время, 
# когда он последний раз был на сайте)

users_data = events_data.groupby('user_id', as_index=False)\
    .agg({'timestamp':'max'})\
        .rename(columns={'timestamp':'last_seen'})

users_data.head()
# Out:
#    user_id   last_seen
# 0        1  1472827464
# 1        2  1519226966
# 2        3  1444581588
# 3        5  1499859939
# 4        7  1521634660

# %% [markdown]
# #### 2) добавим новый столбец, в котором рассчитаем сколько времени пользователь не был сайте НА ТЕКУЩИЙ МОМЕНТ
#
# последний момент времени (из которого будем вычитать метку) возьмем как последнее значение из таблицы (по сути это текущее время, если бы на дворе было 2018-05-19 23:33:31) - значение равно 1526772811

# %%
events_data.tail()
# Out:
#          step_id   timestamp      action  user_id                date  \
# 3480698    33375  1526772685      viewed    11677 2018-05-19 23:31:25
# 3480699    32815  1526772750      viewed     5198 2018-05-19 23:32:30
# 3480700    32815  1526772750  discovered     5198 2018-05-19 23:32:30
# 3480701    32815  1526772750      passed     5198 2018-05-19 23:32:30
# 3480702    33892  1526772811      viewed    18526 2018-05-19 23:33:31
#
#                 day
# 3480698  2018-05-19
# 3480699  2018-05-19
# 3480700  2018-05-19
# 3480701  2018-05-19
# 3480702  2018-05-19

# %%
users_data['is_gone_user'] = 1526772811- users_data.last_seen

users_data
# Out:
#        user_id   last_seen  is_gone_user
# 0            1  1472827464      53945347
# 1            2  1519226966       7545845
# 2            3  1444581588      82191223
# 3            5  1499859939      26912872
# 4            7  1521634660       5138151
# ...        ...         ...           ...
# 19229    26790  1517495987       9276824
# 19230    26793  1510225034      16547777
# 19231    26794  1512035039      14737772
# 19232    26797  1509995096      16777715
# 19233    26798  1520978742       5794069
#
# [19234 rows x 3 columns]

# %% [markdown]
# #### 3) проверим - больше ли эти значения, чем один месяц?
# - если да - значит пользователь ушел (дропнулся)
# - если нет - значит пользователя пока еще нельзя считать бросившим курс

# %% [markdown]
# заведем вспомогательные значения, относительно которых и будем присваивать статус пользователю

# %%
now = 1526772811                # текущее время (если бы на дворе было 2018-05-19 23:33:31) - 
                                    # если решать для текущего времени, то просто берешь команду now из бибилотеки dataime
drop_out_treshold = 2592000     # наш флаг, величина 1 месяца в секундах

# %%
# теперь прописываем условие, что поможет нам превратить заполнение нового столбца в булевые значения True/False

users_data['is_gone_user'] = (now - users_data.last_seen) > drop_out_treshold

users_data
# Out:
#       user_id   last_seen  is_gone_user  correct  wrong
# 0           2  1519226966          True        2      0
# 1           3  1444581588          True       29     23
# 2           5  1499859939          True        2      2
# 3           8  1481466913          True        9     21
# 4          14  1436368676          True        0      1
# ...       ...         ...           ...      ...    ...
# 9935    26787  1498470055          True        3      0
# 9936    26790  1517495987          True        1      0
# 9937    26794  1512035039          True       33      9
# 9938    26797  1509995096          True        2      0
# 9939    26798  1520978742          True        2      1
#
# [9940 rows x 5 columns]

# %% [markdown]
# вывод: считаем, что все, у кого True (больше 30 дней на текущий момент не появлялись) - те ушли с курса

# %% [markdown]
# #### 4) объединим данные из двух датасэтов:
# - в первом хранится информация о том, как пользователь решал задачи (правильно/неправильно) - user_scores
# - во втором - считается ли пользователь дропнувшимся с курса или нет - user_data

# %%
users_scores.head()
# Out:
# submission_status  user_id  correct  wrong
# 0                        2        2      0
# 1                        3       29     23
# 2                        5        2      2
# 3                        8        9     21
# 4                       14        0      1

# %% [markdown]
# #### Используем метод merge():
# - указываем что объединить (первый аргумент)
# - второй аргумент - по какому стобцу: on ='name_col' (по умолчанию метод сам найдет совпадающие по имени столбцы)
# - третий аргумент - что делать, если совпадающих значений в указанном столбце нет: how= 'outer' заполнит значениями Nan
# (по умолчанию просто выкинет эти строки)

# %%
# используем метод merge() - слияние объединение двух датафреймов dataframe 

users_data_false =  users_data.merge(users_scores) # такой код при объединении слиянии датасэтов 
#                                                   выбросит все НЕСОВПАДАЮЩИЕ строки, потому что в users_score содержится
                                                    # меньше юзеров

users_data_false
# Out:
#       user_id   last_seen  is_gone_user  correct  wrong
# 0           2  1519226966          True        2      0
# 1           3  1444581588          True       29     23
# 2           5  1499859939          True        2      2
# 3           8  1481466913          True        9     21
# 4          14  1436368676          True        0      1
# ...       ...         ...           ...      ...    ...
# 9935    26787  1498470055          True        3      0
# 9936    26790  1517495987          True        1      0
# 9937    26794  1512035039          True       33      9
# 9938    26797  1509995096          True        2      0
# 9939    26798  1520978742          True        2      1
#
# [9940 rows x 5 columns]

# %% [markdown]
# СНОВА ПОТЕРЯЛИ ДАННЫЕ!
#
# почему?
#
# потому что в таблице user_scores отсутствует информация о пользователях, которые вообще не пытались решить задачу: в ней содержится только информация о правильных и неправильных ответах.
#
# поэтому при использовании метода merge() нужно указывать информацию о заполнении пустых ячеек для таких случаев

# %%
# вспомогательный код - чтобы заново прогнать данные и получить корректный исходный датасэт для преобразований

users_data = events_data.groupby('user_id', as_index=False)\
    .agg({'timestamp':'max'})\
        .rename(columns={'timestamp':'last_seen'})

users_data['is_gone_user'] = (now - users_data.last_seen) > drop_out_treshold

users_data
# Out:
#        user_id   last_seen  is_gone_user
# 0            1  1472827464          True
# 1            2  1519226966          True
# 2            3  1444581588          True
# 3            5  1499859939          True
# 4            7  1521634660          True
# ...        ...         ...           ...
# 19229    26790  1517495987          True
# 19230    26793  1510225034          True
# 19231    26794  1512035039          True
# 19232    26797  1509995096          True
# 19233    26798  1520978742          True
#
# [19234 rows x 3 columns]

# %% [markdown]
# добавляем аргумент 'outer' в метод merge()

# %%
users_data =  users_data.merge(users_scores, how = 'outer')

users_data

# таким образом мы данные не потеряем
# Out:
#        user_id   last_seen  is_gone_user  correct  wrong
# 0            1  1472827464          True      NaN    NaN
# 1            2  1519226966          True      2.0    0.0
# 2            3  1444581588          True     29.0   23.0
# 3            5  1499859939          True      2.0    2.0
# 4            7  1521634660          True      NaN    NaN
# ...        ...         ...           ...      ...    ...
# 19229    26790  1517495987          True      1.0    0.0
# 19230    26793  1510225034          True      NaN    NaN
# 19231    26794  1512035039          True     33.0    9.0
# 19232    26797  1509995096          True      2.0    0.0
# 19233    26798  1520978742          True      2.0    1.0
#
# [19234 rows x 5 columns]

# %% [markdown]
# заменим значения Nan на нули

# %%
users_data.fillna(0)
# Out:
#        user_id   last_seen  is_gone_user  correct  wrong
# 0            1  1472827464          True      0.0    0.0
# 1            2  1519226966          True      2.0    0.0
# 2            3  1444581588          True     29.0   23.0
# 3            5  1499859939          True      2.0    2.0
# 4            7  1521634660          True      0.0    0.0
# ...        ...         ...           ...      ...    ...
# 19229    26790  1517495987          True      1.0    0.0
# 19230    26793  1510225034          True      0.0    0.0
# 19231    26794  1512035039          True     33.0    9.0
# 19232    26797  1509995096          True      2.0    0.0
# 19233    26798  1520978742          True      2.0    1.0
#
# [19234 rows x 5 columns]

# %% [markdown]
# вспомним, что у нас есть таблица, в которой хранится информация обо всех действиях каждого пользователя
#
# сохраним ее в новую переменную

# %%
users_events_data = events_data.pivot_table(index='user_id', 
                        columns='action', 
                        values='step_id', 
                        aggfunc='count', 
                        fill_value=0).reset_index()

users_events_data
# Out:
# action  user_id  discovered  passed  started_attempt  viewed
# 0             1           1       0                0       1
# 1             2           9       9                2      10
# 2             3          91      87               30     192
# 3             5          11      11                4      12
# 4             7           1       1                0       1
# ...         ...         ...     ...              ...     ...
# 19229     26790           8       8                1       9
# 19230     26793           1       0                1       1
# 19231     26794          69      69               34     180
# 19232     26797          10      10                2      13
# 19233     26798          12      12                3      12
#
# [19234 rows x 5 columns]

# %% [markdown]
# #### 5) Присоединим эти данные к уже имеющимся:

# %%
users_data = users_data.merge(users_events_data, how='outer')

users_data =users_data.fillna(0)

users_data
# Out:
#        user_id   last_seen  is_gone_user  correct  wrong  discovered  passed  \
# 0            1  1472827464          True      0.0    0.0           1       0
# 1            2  1519226966          True      2.0    0.0           9       9
# 2            3  1444581588          True     29.0   23.0          91      87
# 3            5  1499859939          True      2.0    2.0          11      11
# 4            7  1521634660          True      0.0    0.0           1       1
# ...        ...         ...           ...      ...    ...         ...     ...
# 19229    26790  1517495987          True      1.0    0.0           8       8
# 19230    26793  1510225034          True      0.0    0.0           1       0
# 19231    26794  1512035039          True     33.0    9.0          69      69
# 19232    26797  1509995096          True      2.0    0.0          10      10
# 19233    26798  1520978742          True      2.0    1.0          12      12
#
#        started_attempt  viewed
# 0                    0       1
# 1                    2      10
# 2                   30     192
# 3                    4      12
# 4                    0       1
# ...                ...     ...
# 19229                1       9
# 19230                1       1
# 19231               34     180
# 19232                2      13
# 19233                3      12
#
# [19234 rows x 9 columns]

# %% [markdown]
# #### 6) добавим число уникальных дней, проведенных пользователем на сайте

# %% [markdown]
# посчитаем число уникальных дней:
# - сгруппируем исходный датасэт по пользователям
# - возьмем столбец день
# - применим функцию посчитать уникальные значения столбца nunique
# - переведем полученную серию в dataFrame командой to_frame
# - сбросим индексы, чтобы user_id из индексов перешел в имя столбца со значениями
#
# по сути, этот столбец будет отображать, сколько дней пользователь провел на сайте

# %%
users_days = events_data.groupby('user_id')\
    .day.nunique()\
        .to_frame()\
            .reset_index()

users_days
# Out:
#        user_id  day
# 0            1    1
# 1            2    2
# 2            3    7
# 3            5    2
# 4            7    1
# ...        ...  ...
# 19229    26790    4
# 19230    26793    1
# 19231    26794    9
# 19232    26797    2
# 19233    26798    1
#
# [19234 rows x 2 columns]

# %% [markdown]
# обеъдиним результат в уже имеющуюся таблицу пользовательских данных

# %%
users_data = users_data.merge(users_days, how='outer')

users_data
# Out:
#        user_id   last_seen  is_gone_user  correct  wrong  discovered  passed  \
# 0            1  1472827464          True      0.0    0.0           1       0
# 1            2  1519226966          True      2.0    0.0           9       9
# 2            3  1444581588          True     29.0   23.0          91      87
# 3            5  1499859939          True      2.0    2.0          11      11
# 4            7  1521634660          True      0.0    0.0           1       1
# ...        ...         ...           ...      ...    ...         ...     ...
# 19229    26790  1517495987          True      1.0    0.0           8       8
# 19230    26793  1510225034          True      0.0    0.0           1       0
# 19231    26794  1512035039          True     33.0    9.0          69      69
# 19232    26797  1509995096          True      2.0    0.0          10      10
# 19233    26798  1520978742          True      2.0    1.0          12      12
#
#        started_attempt  viewed  day
# 0                    0       1    1
# 1                    2      10    2
# 2                   30     192    7
# 3                    4      12    2
# 4                    0       1    1
# ...                ...     ...  ...
# 19229                1       9    4
# 19230                1       1    1
# 19231               34     180    9
# 19232                2      13    2
# 19233                3      12    1
#
# [19234 rows x 10 columns]

# %% [markdown]
# #### 7) обязательно проверяем не потеряли ли мы кого-то?!?

# %%
users_data.user_id.nunique()    # пользователи в полученной таблице
# Out:
# 19234

# %%
events_data.user_id.nunique()   # пользователи в исходной таблице
# Out:
# 19234

# %% [markdown]
# нет, все пользователи на месте

# %% [markdown]
# #### 8) создаем колонку , показывающую прошел ли студент курс
# - для этого определим, что достаточным значением РЕШЕННЫХ степов является 170 (считаем процентом от всех степов)

# %%
users_data['passed_course'] = users_data.passed> 170

users_data
# Out:
#        user_id   last_seen  is_gone_user  correct  wrong  discovered  passed  \
# 0            1  1472827464          True      0.0    0.0           1       0
# 1            2  1519226966          True      2.0    0.0           9       9
# 2            3  1444581588          True     29.0   23.0          91      87
# 3            5  1499859939          True      2.0    2.0          11      11
# 4            7  1521634660          True      0.0    0.0           1       1
# ...        ...         ...           ...      ...    ...         ...     ...
# 19229    26790  1517495987          True      1.0    0.0           8       8
# 19230    26793  1510225034          True      0.0    0.0           1       0
# 19231    26794  1512035039          True     33.0    9.0          69      69
# 19232    26797  1509995096          True      2.0    0.0          10      10
# 19233    26798  1520978742          True      2.0    1.0          12      12
#
#        started_attempt  viewed  day  passed_course
# 0                    0       1    1          False
# 1                    2      10    2          False
# 2                   30     192    7          False
# 3                    4      12    2          False
# 4                    0       1    1          False
# ...                ...     ...  ...            ...
# 19229                1       9    4          False
# 19230                1       1    1          False
# 19231               34     180    9          False
# 19232                2      13    2          False
# 19233                3      12    1          False
#
# [19234 rows x 11 columns]

# %% [markdown]
# #### 9) сгруппируем итоговые данные по столбцу заверешенных (решенных) степов и посчитаем число пользователей
# - в данном случае мы считаем количество вариантов, которые мы сгруппировали: число True и число False в графе passed_course

# %%
test_passed_users = users_data.groupby('passed_course').count()

test_passed_users
# Out:
#                user_id  last_seen  is_gone_user  correct  wrong  discovered  \
# passed_course
# False            17809      17809         17809    17809  17809       17809
# True              1425       1425          1425     1425   1425        1425
#
#                passed  started_attempt  viewed    day
# passed_course
# False           17809            17809   17809  17809
# True             1425             1425    1425   1425

# %% [markdown]
# посмотрим какой процент тех, что доучился, ко всем студентам
#
# зачем?
#
# еще одна проверка: средний процент по индустрии 5-10%

# %%
print(f"Процент людей, закончивших курс = {round((test_passed_users.loc[True]['user_id']) /(test_passed_users.loc[False]['user_id'] + test_passed_users.loc[True]['user_id'])) *100}%")

# выведет 7%

# %%
users_data['passed_course'].value_counts(normalize=True)*100 # второй способ
# Out:
# False    92.591245
# True      7.408755
# Name: passed_course, dtype: float64

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
