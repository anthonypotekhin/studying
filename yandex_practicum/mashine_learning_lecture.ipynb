# %% [markdown]
# ### Машинное обучение

# %% [markdown]
# #### Урок 1. Моделирование и машинное обучение

# %% [markdown]
# Машинное обучение всегда идёт по одной и той же схеме:
#
# 1) Подготовка учебного материала — эталонных данных. (разметка)
# 2) Обучение, тестирование и запуск модели для предсказаний.
# 3) Поддержка готовой модели, чтобы она сохраняла точность.

# %% [markdown]
# Схема работы с Моделью машиннного обучения
#
# ![image.png](attachment:image.png)

# %% [markdown]
#     Существует три вида машинного обучения: с учителем, без учителя и с подкреплением

# %% [markdown]
# ##### Обучение с учителем

# %% [markdown]
# Самый простой вариант научить машину делать выводы — показать ей правильные ответы столько раз, чтобы она их выучила. Компьютер сможет легко узнавать леопардов, если загрузить достаточно картинок и отметить, где среди них именно эти звери.
#
# Так работает обучение с учителем:
#
# - Модель сразу получает весь учебный датасет — признаковое описание объекта.
# - В признаковом описании объекта есть столбец с целевым признаком — например названием животного.
# - Значения целевого признака указаны. <font color='red'>Заранее размеченные данные — это и есть учитель.</font>
#
# По правильным примерам, то есть с учителем, компьютер можно научить решать четыре класса задач: регрессии, классификации, ранжирования и рекомендации.

# %% [markdown]
# <font color='red'>**Регрессия**</font> Популярная задача по прогнозу числовых показателей. Пример регрессии — предсказание стоимости квартиры по количеству комнат, метражу, удалённости от центра города и другим параметрам.
#
# <font color='red'>**Классификация**</font>. Ещё одна частая задача — отнести объект к одному из классов. Например, для модерации текстов: они либо содержат запрещённую лексику, либо нет.
#
# <font color='red'>**Ранжирование**</font>. Если компьютер должен расставить объекты в каком-то порядке — значит, это задача ранжирования. Типичный пример — работа поисковой системы. Любой поисковик определяет, какую веб-страницу показать в выдаче первой, какую — второй… То есть присваивает им ранг — ранжирует.
#
# <font color='red'>**Рекомендация**</font>. Задача рекомендации тесно связана с ранжированием, но они разные. Ранжирование отвечает на прямой запрос пользователя и выстраивает варианты ответов в лучшем порядке. Рекомендация позволяет предложить пользователю то, о чëм он не спрашивал, но чем может заинтересоваться.

# %% [markdown]
# ##### Обучение с подкреплением

# %% [markdown]
# В обучении с учителем есть один минус. Как вы знаете, при таком подходе целевые признаки рассчитывают по их прежним значениям в связке с другими свойствами объекта. Из-за этого предсказания получаются статистически верными, но не учитывают изменения данных в процессе обучения модели. А вдруг мир за это время станет другим — какие тогда регрессии? К тому же как быть, если правильных решений задачи ещё нет? В таких случаях компьютеру приходится учиться без подсказок — методом проб и ошибок. Машина будет ориентироваться на результат своих действий, хороший или плохой. Такой способ называется обучением с подкреплением. Вот его свойства:
#
# - Есть целевой признак — например прибыль от покупки и продажи акций. В этом смысле всё как в обучении с учителем.
#
# - Нет заранее подготовленного датасета. Учебные данные поступают из среды, в которой учится модель. Пример такой среды — биржа.
# - Нет самого учителя — то есть примеров правильных решений. Компьютер вырабатывает их самостоятельно. <font color='green'>Если модель МО — это робот для трейдинга, то она будет запоминать, какие её действия принесли прибыль, а какие — убыток</font>. Поэтому обучение — с подкреплением.

# %% [markdown]
# почему бы не обучить робота для трейдинга с помощью регрессии? Ведь он не первый на свете покупает и продаёт акции. Дело в том, что некоторые бизнес-цели требуют анализировать информацию сразу же после того, как она поступила. В торговле на бирже большую роль играют новости. Одни мировые события цикличны, а другие непредсказуемы и происходят один раз, но сильно влияют на рынок. Чтобы прогнозировать котировки акций как можно эффективнее, нужно постоянно обновлять учебные данные и выводы о верных действиях. Обучение с подкреплением не панацея, но регрессия и вовсе здесь бесполезна. Она учит по старым данным.
#
# В обучении с подкреплением пока не выделили классы задач.

# %% [markdown]
# ##### Обучение без учителя

# %% [markdown]
# В обучении без учителя машина ищет не целевой признак одного объекта, а любые закономерности на уровне объектов. Это полезно в задачах кластеризации и снижения размерности.
#
# <font color='red'>Кластеризация</font>. Группировка объектов по их признакам. Модель сама решает по каким.
# С помощью кластеризации можно, например, распределить клиентов по предпочтениям и делать им подходящие предложения.
#
# <font color='red'>Снижение размерности</font>. Бывает, что в признаковом описании указано слишком много свойств объекта — сотни, тысячи. Моделям машинного обучения тяжело делать выводы по такому количеству возможных переменных. Значит, лучше его уменьшить. Специалист по Data Science может сгруппировать признаки вручную, но задача снижения размерности помогает не тратить на это время.
#
# Вот основные черты обучения без учителя:
# - Целевого признака нет, потому что задача — выявить закономерности между объектами, а не признаками.
#
# - Примеров правильных решений тоже нет. По ходу обучения компьютер делает выводы сам — без учителя.
# - В отличие от обучения с подкреплением, все учебные данные есть изначально. Так же, как в обучении с учителем.

# %% [markdown]
# Обощенная схема моделей с учителем, подкреплением, без учителя
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Урок 2. Модель линейной регрессии и Библиотека sklearn

# %% [markdown]
# Наглядный пример отличия задач регрессии от других задач
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Обращаться к <font color='red'>регрессии</font> как к классу задач можно только если нужно спрогнозировать <font color='red'>непрерывный количественный показатель</font>

# %% [markdown]
# ##### Входные и целевые признаки объекта

# %% [markdown]
# Пример входных и целевых признаков, если стоит задача предугадать <font color='red'>**вес** </font> котов разных пород и окраса в определённом возрасте.
#
# ![image.png](attachment:image.png)

# %%
import sklearn
sklearn.__version__
# Out:
# '1.1.3'

# %% [markdown]
# ##### Тренировочные, валидационные и тестовые данные

# %% [markdown]
# После обучения проводят дополнительную настройку модели — первичную валидацию.
#
# Новые данные нужны для трёх процедур: обучения модели, первичной валидации и тестов. Чтобы обеспечить весь процесс наблюдениями, датасет от заказчика разбивают на три части — тренировочную, валидационную и тестовую выборки.
#
# <font color='red'>Тренировочная выборка.</font> Её также называют обучающей. Это набор объектов, на котором учится модель МО.
#
# <font color='red'>Валидационная выборка</font>. После обучения специалисты часто корректируют модель дополнительными параметрами. Как понять, что добавить в формулу? Нужно дать модели поработать на данных, которые отличаются от тренировочных, и заметить ошибки. Тогда станет ясно, как их исключить. Для этих целей нужна отдельная выборка данных — валидационная. Не все базовые модели требуют донастройки, поэтому валидационную выборку выделяют не всегда.
#
# <font color='red'>Тестовая выборка</font>. Настройка модели похожа на её тест, но всё же нужен отдельный этап тестирования. Дело в том, что параметры модели подбирают под данные валидационной выборки, но как она отработает на других? Чтобы окончательно убедиться в качестве модели машинного обучения, нужна третья порция свежих данных — тестовая выборка.

# %% [markdown]
# Деление на тренировочную, валидационную и тестовую выборки в соотношении 3:1:1, как на схеме ниже:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Разбивка данных на выборки
#
# - Первым аргументом передать в функцию train_test_split() входные признаки.
#
# - Вторым аргументом передать целевой признак.
# - Третьим аргументом — сообщить размер тестовой выборки, если он отличается от дефолтного в 0.25. Можно указать либо дробное число от 0 до 1, либо целое. В первом случае датасет разделится на доли, а во втором тестовая выборка будет состоять из того количества объектов, которое вы указали целым числом.
# - Добавить в функцию именованный аргумент random_state, чтобы при каждом перезапуске блокнота датасет делился на выборки одинаково. Поясним. Функция train_test_split() разбивает наблюдения по частям рандомно — в тестовую выборку всегда будет попадать, к примеру, четверть строк, но из разных мест в таблице. Если перезапустить блокнот, система повторит это действие. Она поделит данные в прежнем соотношении, но в выборки случайным образом попадут другие строки, а значит, модель отработает с новым результатом. В итоге это приведёт к тому, что данные для обучения и тестирования модели пересекутся, и сделать выводы об этих процедурах будет невозможно. Чтобы такого не случилось, нужно зафиксировать деление датасета на выборки по конкретным строкам. Это и делает аргумент random_state.

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# Функция вернёт список переменных, внутри которых строки с входными признаками тренировочной выборки, входными признаками тестовой выборки, целевым признаком тренировочной выборки и целевым признаком тестовой выборки. Переменные принято называть так:
#
# ![image.png](attachment:image.png)

# %%
# разделение на тренировочную и тестовую выборки
"""
X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y, 
    random_state=RANDOM_STATE
)

"""
# Out:
# '\nX_train, X_test, y_train, y_test = train_test_split(\n    X, \n    y, \n    random_state=RANDOM_STATE\n)\n\n'

# %% [markdown]
# ##### Модель линейной регрессии

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Создание и
# Обучение модели

# %%
"""
model_lr = LinearRegression()
model_lr.fit(X_train, y_train)

"""

# %% [markdown]
# Получение коэффициентов

# %%
model_lr.coef_

# %% [markdown]
# Получение интерсепта

# %%
model_lr.intercept_

# %% [markdown]
# Получение предсказания целевого признака на тестовой выборке

# %%
predictions = model_lr.predict(X_test)

# %% [markdown]
#         Линейная регрессия подбирает независимые коэффициенты и интерсепт по логике наименьших квадратов: считает разницу между значением целевой переменной "предсказанной" и "фактической". Чем меньше сумма квадратов таких разностей - тем точнее модель

# %% [markdown]
# Шкала Чеддока для проверки значимости корреляции
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Построим матрицу корреляции и тепловую карту для примера на данных о недвижимости

# %%
import pandas as pd
df_estate = pd.read_csv('/Users/tony_builder/Documents/GitHub/studying/yandex_practicum/data/real_estate_data.csv', sep='\t')

# %%
df_estate.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %%
df_estate.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'cityCenters_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %%
df_estate.shape
# Out:
# (23699, 22)

# %%
import random
df_estate['years_after_repair']= pd.Series((random.randint(0,10) for _ in range(23699)))

# %%
df_estate.years_after_repair.unique()
# Out:
# array([ 2, 10,  3,  9,  4,  1,  0,  7,  5,  6,  8])

# %%
df_estate_clean = df_estate[['total_area', 'living_area', 'ceiling_height', 'rooms','cityCenters_nearest',  'years_after_repair', 'last_price']]

# %%
df_estate_clean.corr()
# Out:
#                      total_area  living_area  ceiling_height     rooms  \
# total_area             1.000000     0.939537        0.095490  0.758344
# living_area            0.939537     1.000000        0.090650  0.845977
# ceiling_height         0.095490     0.090650        1.000000  0.054457
# rooms                  0.758344     0.845977        0.054457  1.000000
# cityCenters_nearest   -0.231446    -0.231368       -0.091689 -0.184864
# years_after_repair    -0.002672    -0.006090        0.009108 -0.006682
# last_price             0.653675     0.566492        0.085430  0.363343
#
#                      cityCenters_nearest  years_after_repair  last_price
# total_area                     -0.231446           -0.002672    0.653675
# living_area                    -0.231368           -0.006090    0.566492
# ceiling_height                 -0.091689            0.009108    0.085430
# rooms                          -0.184864           -0.006682    0.363343
# ...

# %% [markdown]
# Строим тепловую карту визуализации корреляции
#
# Делаем это с помощью метода heatmap из библиотеки seaborn. Первым аргументом нужно передать матрицу, потом для отображения коэффициентов на карте задать параметр annot=True, а затем — fmt='.2f', чтобы оставить только два знака после запятой у коэффициентов:

# %%
# импорт библиотеки seaborn
import seaborn as sns

# построение тепловой карты
sns.heatmap(df_estate_clean.corr(), annot=True, fmt='.2f')
# Out:
# <AxesSubplot: >

# %% [markdown]
# Теперь посмотрим как справляется модель, которая использует почищенные данные для предсказания

# %%
# необходимые импорты
import pandas as pd

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split


# создание константы RANDOM_STATE
RANDOM_STATE = 42


# считывание CSV-файла в датафрейм pandas, сохранение выборок
df = df_estate_clean.dropna()
X = df.drop('last_price', axis=1)
y = df['last_price']
X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y, 
    random_state=RANDOM_STATE
)

# инициализация и обучение модели
model_lr  = LinearRegression()
model_lr.fit(X_train, y_train)

# предсказанные значения для X_test
predictions = model_lr.predict(X_test)

# вывод первых предсказанного и настоящего значений
print(predictions[0], y_test.head(1))
# Out:
# 4869751.401785357 19648    4900000.0
# Name: last_price, dtype: float64

# %% [markdown]
# значения предсказанной цены и фактической очень похожи

# %% [markdown]
# ##### Качество модели МО

# %% [markdown]
# <font color='red'>Среднеквадратичная ошибка</font>
#
# Помните, как работает метод наименьших квадратов ошибок? Он считает сумму квадратов всех ошибок среди предсказанных целевых признаков. Сама по себе эта сумма ничего не говорит о качестве модели, ведь одно и то же отклонение на тысячу и миллион строк — совершенно разный результат.
#
# Но если разделить сумму квадратов ошибок на число объектов прогноза, то получится средний квадрат ошибки.
#
# Это и есть MSE:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# Считаем значение сердеквадратичной ошибки

# %%
y_pred, y_true  =  predictions, y_test
mse = mean_squared_error(y_true, y_pred)
mse
# Out:
# 29325968041198.902

# %% [markdown]
# <font color='red'>Корень среднеквадратичной ошибки</font>
#
# Хорошо, что можно посчитать MSE и не пролистывать мышкой сотни тысяч строк. Но будем честными: значения этой метрики выглядят громоздко. В предсказании цены квартир модель в среднем ошибается на
# 327342872169.86914
# (руб 2
#  ) — как это понять?
#
#  Чтобы было удобнее оценить качество модели, специалисты по Data Science вычисляют корень среднеквадратичной ошибки (англ. Root Mean Squared Error, RMSE):
#
#  ![image.png](attachment:image.png)

# %%
rmse = mean_squared_error(y_true, y_pred, squared=False)
rmse
# Out:
# 5415345.6068102345

# %% [markdown]
# Получается, что в среднем модель ошибается на сумму 541 345 руб

# %% [markdown]
# ##### Схема работы с моделью машинного обучения
#
# 1) Анализ бизнес-задачи. Сперва всегда нужно обдумать запрос заказчика. Это поможет подобрать вид и задачу машинного обучения так, чтобы достичь цели бизнеса.
#
# 2) Сбор данных. Для машинного обучения необходимы данные. Бывает, что датасет предоставляет заказчик, а иногда его приходится собирать самостоятельно. Как вариант, запросить у дата-инженеров.
# 3) Предобработка данных. Дубликаты, аномалии и пропуски искажают результаты машинного обучения. Обязательно нужно очистить датасет.
# 4) Исследовательский анализ данных. Хорошее исследование позволит окончательно определиться с базовой моделью МО.
# 5) Подготовка данных к машинному обучению. Данные готовят по-разному в зависимости от задачи, но в этот этап всегда входят разметка и деление на выборки. Если задача позволяет обучить только одну модель, которую не нужно настраивать, то данные достаточно разделить на тренировочную и тестовую выборки.
# 6) Обучение модели. Здесь всё ясно: это этап обучения модели на тренировочной выборке данных.
# 7) Тестирование модели. Когда модель обучена, нужно получить предсказания модели на тестовой выборке и проверить результат с помощью метрик качества.
# 8) Интерпретация результатов. Специалисты по Data Science выделяют трактование метрик качества и презентацию модели заказчику в отдельный этап.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Урок 3. Линейная алгебра и библиотека numpy

# %% [markdown]
# ##### Простейшие операции с векторами

# %%
# создадие вектор-столбца на основе списка

import numpy as np 

nested_list_with_numbers = [
    [1], 
    [2], 
    [3], 
    [4], 
    [5]
]
vector_column = np.array(nested_list_with_numbers)

vector_column
# Out:
# array([[1],
#        [2],
#        [3],
#        [4],
#        [5]])

# %% [markdown]
# Сложение векторов - это сумма их координат. Результат - тоже вектор

# %% [markdown]
# Вся суть применения операций над векторами в том, что любую строку в датафрейме (которая имеет количественные значения), можно представить в виде вектора.
#
# А потом производить операции над векторами, например сложение

# %% [markdown]
# Как пример - задача:
#
# ![image.png](attachment:image.png)

# %%
# необходимые импорты
import numpy as np

# список с характеристиками первой квартиры
flat_1 = [67.0, 26.8, 3.0, 3686400.0]
# список с характеристиками второй квартиры
flat_2 = [47.4, 27.5, 1.0, 2037580.0]

# создание массивов np из списков
vector_1 = np.array(flat_1)
vector_2 = np.array(flat_2)

# создание массива из суммы двух массивов
vector_3 = vector_1 + vector_2

# вывод полученного сложением массива
print(vector_3)
# Out:
# [1.14400e+02 5.43000e+01 4.00000e+00 5.72398e+06]

# %%
# сложение списков даст по сути их объединение (то есть расширение - extend)
flat_1+flat_2
# Out:
# [67.0, 26.8, 3.0, 3686400.0, 47.4, 27.5, 1.0, 2037580.0]

# %% [markdown]
# Поэтому перевод в векторный тип оправдан для такого типа операций

# %% [markdown]
# Пример на вычитание векторов
#
# ![image.png](attachment:image.png)

# %%
# необходимые импорты
import numpy as np

# список с общими площадями квартир
total_area = [72.9, 64.0, 63.0, 75.0, 64.6, 63.2, 57.0, 59.4, 100.3, 86.5]
# список с жилыми площадями квартир
living_area = [47.4, 35.8, 30.9, 45.0, 34.2, 28.4, 23.4, 35.0, 50.1, 45.0]

# создание массивов np из списков
vector_1 = np.array(total_area)
vector_2 = np.array(living_area)

# создание массива из разности двух массивов
vector_3 = vector_1-vector_2

# вывод полученного вычитанием массива
print(vector_3)
# Out:
# [25.5 28.2 32.1 30.  30.4 34.8 33.6 24.4 50.2 41.5]

# %% [markdown]
# Пример на умножение вектора на скаляр
#
# ![image.png](attachment:image.png)

# %%
# необходимые импорты
import numpy as np

# список с ценами квартир
prices = [4265600.0, 3885760.0, 3434000.0, 4510000.0, 5103200.0]

# создание массива np из списка
vector_1 = np.array(prices)
# создание необходимого числа
number = 1.1

# создание массива умножением на число
vector_2 = vector_1 * number

# вывод полученного умножением на число массива
print(vector_2)
# Out:
# [4692160. 4274336. 3777400. 4961000. 5613520.]

# %% [markdown]
# Пример на деление ветора на скаляр
#
# ![image.png](attachment:image.png)

# %%
# необходимые импорты
import numpy as np

# список с ценами квартир
prices = [4265600.0, 3885760.0, 3434000.0, 4510000.0, 5103200.0]

# создание массива np из списка
vector_1 = np.array(prices)
# создание необходимого числа
number = 1000

# создание массива делением на число
vector_2 = vector_1/ number

# вывод полученного делением на число массива
print(vector_2)
# Out:
# [4265.6  3885.76 3434.   4510.   5103.2 ]

# %% [markdown]
# Умножение векторов
#
# Поэлементное умножение и деление двух векторов - это поэлементное умножение их координат
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Пример на умножение векторов
#
# ![image.png](attachment:image.png)

# %%
# необходимые импорты
import numpy as np

# массив с ценами квартир за метр
prices_per_meter = np.array([49600, 60715, 50500, 50000, 63790])

# массив с общими площадями квартир
total_areas = np.array([86 , 64 , 68 , 90.2, 80])

# создание массива поэлементным умножением
prices = prices_per_meter * total_areas

# вывод массива, полученного поэлементным умножением
print(prices)
# Out:
# [4265600. 3885760. 3434000. 4510000. 5103200.]

# %% [markdown]
# ##### Скалярное произведение векторов
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Скалярное произведение по элементам векторов
#
#     Рассчитать угол между векторами, за которыми в работе сайентиста скрываются строки и столбцы, на практике сложно. Как же тогда посчитать их скалярное произведение? Есть один удобный способ. Нужно поэлементно умножить эти векторы, а потом сложить координаты вектора-произведения. Вот формула такого действия:
#
#
# ![image.png](attachment:image.png)

# %%
# скалярное произведение векторов считают так: 

dot_product = (a * b).sum()

# %% [markdown]
# Пример использования скалярного произведения
#
# ![image.png](attachment:image.png)

# %%
# необходимые импорты
import numpy as np

# вектор с коэффициентами
coefs = np.array([
    -472792, 58467,  -7652, 387841,  55630, -47147, -49522
])

# вектор с константой и характеристиками квартиры
flat_test = np.array([1, 44, 27, 2.9, 2, 1.7, 2])

# создание переменной, содержащей скалярное произведение
price = (coefs * flat_test).sum()

# вывод получившегося значения
print(price)
# Out:
# 2949957.0

# %% [markdown]
# Либо можно использовать встроенную функцию dot

# %%
# необходимые импорты
import numpy as np

# вектор с коэффициентами
coefs = np.array([
    -472792, 58467,  -7652, 387841,  55630, -47147, -49522
])

# вектор с константой и характеристиками квартиры
flat_test = np.array([1, 44, 27, 2.9, 2, 1.7, 2])

# создание переменной, содержащей скалярное произведение
price = np.dot(coefs, flat_test)

# вывод получившегося значения
print(price)
# Out:
# 2949957.0

# %% [markdown]
# ##### Косинусное расстояние
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Как узнать косинус угла между векторами? обратным счетом
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Пример на вычисление косинуса
#
# ![image.png](attachment:image.png)

# %%
a= np.array([10,-2,6,-2])
b= np.array([0,-4,8,1])

res = 1 - np.dot(a,b) / (np.linalg.norm(a) * np.linalg.norm(b))

# длина вектора считается np.linalg.norm(a)

res
# Out:
# 0.5

# %%
# или используем рукописную функцию

# необходимые импорты
import numpy as np


def get_d_cos(a, b):
    # скалярное произведение a и b
    dot_product = np.dot(a,b) 
    # длина a
    norma_a = np.linalg.norm(a)
    # длина b
    norma_b = np.linalg.norm(b)
    # косинус угла между a и b
    cos = dot_product/(norma_a * norma_b)
    # косинусное расстояние
    d_cos = 1 - cos
    return d_cos

 
# векторы a и b
a = np.array([10, -2, 6, -2])
b = np.array([0, -4, 8, 1])

# косинусное расстояние
d_cos_a_b = get_d_cos(a,b)

# вывод полученного значения
print(d_cos_a_b)
# Out:
# 0.5

# %%
# или lambda -функцию 
a = np.array([10, -2, 6, -2])
b = np.array([0, -4, 8, 1])

# функция расчета косинусного расстояния между двумя векторами
get_d_cos = lambda x,y: 1 - np.dot(x,y) /(np.linalg.norm(x) * np.linalg.norm(y))

d_cos_a_b = get_d_cos(a,b)

d_cos_a_b
# Out:
# 0.5

# %%
# косинусное расстояние из библиотеки scipy

from scipy.spatial.distance import cosine

d_cos = cosine(a, b)

d_cos
# Out:
# 0.5

# %% [markdown]
# Пример на использование косинусного расстояния
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
# необходимые импорты
import numpy as np


# та же функция, написанная в одну строку
def get_d_cos(a, b):
    return 1 - a.dot(b) / (np.linalg.norm(a) * np.linalg.norm(b))


# вектор с данными первой квартиры
flat_1 = np.array([50, 3000000])

# вектор с данными второй квартиры
flat_2 = np.array([50, 4000000])

# вектор с данными третьей квартиры
flat_3 = np.array([100, 6000000])

# косинусное расстояние между первой и второй квартирами
d_cos_1_2 = get_d_cos(flat_1, flat_2)

# косинусное расстояние между первой и третьей квартирами
d_cos_1_3 = get_d_cos(flat_1, flat_3)

# вывод полученных значений
print(d_cos_1_2, d_cos_1_3, sep='\n')
# Out:
# 8.680611784939174e-12
# 0.0

# %% [markdown]
# ##### Евклидово расстояние
# Евклидово расстояние — это ещё один популярный способ сравнивать векторы. Величина представляет собой отрезок между концами двух векторов и обозначается как
# d:
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Пример на использование эвклидова расстояния
#
# ![image.png](attachment:image.png)

# %%
# необходимые импорты
import numpy as np


# та же функция, написанная в одну строку
def get_d(a, b):
    return (((a - b)**2).sum())**0.5


# вектор с данными первой квартиры
flat_1 = np.array([50., 3000000.])

# вектор с данными второй квартиры
flat_2 = np.array([50., 4000000.])

# вектор с данными третьей квартиры
flat_3 = np.array([100., 6000000.])

# евклидово расстояние между первой и второй квартирами
d_1_2 = get_d(flat_1, flat_2)

# евклидово расстояние между первой и третьей квартирами
d_1_3 = get_d(flat_1, flat_3)

# вывод получившихся значений
print(d_1_2, d_1_3)
# Out:
# 1000000.0 3000000.0004166667

# %% [markdown]
# Евклидово расстояние между первой и третьей квартирами больше, чем между первой и второй. Значит, предложить клиенту стоит вторую квартиру. На графике ниже видно, как связаны евклидовы расстояния и цены.
#
# Векторы  a,b,c,
# представляют собой квартиры. Посмотрите: чем больше евклидово расстояние между векторами-квартирами, тем сильнее различается их цена. В данном случае определить более подходящий лот можно было бы и без расчёта евклидова расстояния — просто по оси
# y.
#
# Причина в том, что на плоскости всё видно невооружённым глазом. Если бы речь шла о векторах с длинным списком координат, то есть о многомерном пространстве, без вычислений бы никак не обошлось.
#
#
# Снова показан график стоимости квартир. По оси x отмечена общая площадь в квадратных метрах, а по оси y — цена в рублях. На рисунке изображены векторы a, b, c и два угла: между векторами a и b  и между векторами a и c. Векторы a и c лежат на одной прямой и смотрят в одну сторону, то есть их направление совпадает. Поэтому угол между ними равен нулю. Направление векторов a и b различается. Отмечены два евклидовых расстояния: между концами векторов  a и b и между концами векторов a и c.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Используем готовый код для евклидово расстояния

# %%
from scipy.spatial.distance import euclidean

d_cos = euclidean(flat_1, flat_2)

d_cos
# Out:
# 1000000.0

# %% [markdown]
# ##### Интерпретация косинусного и евклидова расстояний
#
# Мы рассчитали два вида расстояний и, на первый взгляд, получили противоречивый результат. Косинусное расстояние указывало на сходство первой квартиры с третьей, а евклидово — со второй.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# Так какую метрику выбрать, чтобы сравнить эти векторы? Зависит от случая.
#
# - Косинусное расстояние можно использовать, когда «работает» только направление векторов, а их длина не влияет на решение задачи. С такой ситуацией вы столкнулись, когда нужно было сравнить квартиры по стоимости квадратного метра.
#
# - Поскольку речь шла о двух признаках — цене и площади квартиры, — данным соответствовал график двухмерного пространства. Если изобразить на таком одинаковые по длине векторы-квартиры под разными углами, то цена за квадратный метр у них будет различаться, несмотря на одинаковые длины векторов. Выходит, что при такой задаче не нужно сравнивать векторы по длине. Это могло бы исказить вывод о схожести векторов по нужному параметру. Ведь он от длины векторов не зависит.
#
# - Евклидово расстояние учитывает не только направление векторов, но и длину, поэтому оно не помогло бы найти квартиру с близкой ценой за квадрат. Для такой задачи как раз подходит расстояние косинусное, которое зависит только от направления векторов — то есть угла между ними.
# - Зато евклидово расстояние даёт возможность сравнить векторы по элементам, то есть по значению координат. Например, векторы-квартиры — по их общей стоимости и/или площади. А ведь это и требовалось в последней задаче урока: подобрать квартиру с похожей ценой.
